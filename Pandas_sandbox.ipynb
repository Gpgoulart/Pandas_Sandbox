# %%
import pandas as pd

# %%
oo = pd.read_csv('/content/Olympic.csv', encoding='latin-1')
oo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %% [markdown]
# #Value_counts()

# %%
oo.Sport.value_counts()
# Out:
# Aquatics             2210
# Athletics            1523
# Rowing               1377
# Hockey                817
# Gymnastics            783
# Handball              780
# Volleyball            695
# Canoe / Kayak         672
# Football              669
# Basketball            646
# Fencing               606
# Wrestling             533
# Cycling               483
# Equestrian            423
# Sailing               417
# Boxing                416
# Judo                  396
# Shooting              345
# Baseball              335
# Weightlifting         311
# Softball              180
# Archery               162
# Table Tennis          120
# Badminton             120
# Tennis                118
# Modern Pentathlon      81
# Taekwondo              80
# Triathlon              18
# Name: Sport, dtype: int64

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
oo.sort_values(by=['City', 'Sport']).head(10)
# Out:
#          City    Year     Sport Discipline  \
# 11393  Athens  2004.0  Aquatics     Diving
# 11394  Athens  2004.0  Aquatics     Diving
# 11395  Athens  2004.0  Aquatics     Diving
# 11396  Athens  2004.0  Aquatics     Diving
# 11397  Athens  2004.0  Aquatics     Diving
# 11398  Athens  2004.0  Aquatics     Diving
# 11399  Athens  2004.0  Aquatics     Diving
# 11400  Athens  2004.0  Aquatics     Diving
# 11401  Athens  2004.0  Aquatics     Diving
# 11402  Athens  2004.0  Aquatics     Diving
#
#                                     Event              Athlete Gender  \
# 11393                      3m springboard  DESPATIE, Alexandre    Men
# 11394                      3m springboard       SAUTIN, Dmitry    Men
# 11395                      3m springboard    PAKHALINA, Ioulia  Women
# 11396  synchronized diving 3m springboard      NEWBERY, Robert    Men
# 11397  synchronized diving 3m springboard        BIMIS, Thomas    Men
# ...

# %%
oo.City.sort_values().head(10)
# Out:
# 11630    Athens
# 12870    Athens
# 12869    Athens
# 12868    Athens
# 12867    Athens
# 12866    Athens
# 12865    Athens
# 12864    Athens
# 12863    Athens
# 12862    Athens
# Name: City, dtype: object

# %%
oo.Year == "1994"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15428    False
# 15429    False
# 15430    False
# 15431    False
# 15432    False
# Name: Year, Length: 15433, dtype: bool

# %%
oo[oo.Athlete.str.contains('Florence')]

# %% [markdown]
# ## in which events Jesse Owens win a medal?

# %%
jo = oo[oo.Athlete == "BIMIS, Thomas"]
jo
# Out:
#          City    Year     Sport Discipline  \
# 11397  Athens  2004.0  Aquatics     Diving
#
#                                     Event        Athlete Gender Country_Code  \
# 11397  synchronized diving 3m springboard  BIMIS, Thomas    Men          GRE
#
#       Country Event_gender Medal
# 11397  Greece            M  Gold

# %%
jo.Event.value_counts()
# Out:
# synchronized diving 3m springboard    1
# Name: Event, dtype: int64

# %% [markdown]
# which country has won the most men gold medals in single badmonton over the years sort the results alphabeticaly by the players names

# %%
sl = oo[(oo.Medal == 'Gold') & (oo.Gender =='Men') & (oo.Sport == 'Aquatics')]
sl
# Out:
#            City    Year     Sport  Discipline            Event  \
# 2      Montreal  1976.0  Aquatics      Diving   3m springboard
# 8      Montreal  1976.0  Aquatics      Diving     10m platform
# 22     Montreal  1976.0  Aquatics    Swimming   400m freestyle
# 26     Montreal  1976.0  Aquatics    Swimming   100m butterfly
# 28     Montreal  1976.0  Aquatics    Swimming  100m backstroke
# ...         ...     ...       ...         ...              ...
# 13716   Beijing  2008.0  Aquatics  Water polo       water polo
# 13718   Beijing  2008.0  Aquatics  Water polo       water polo
# 13721   Beijing  2008.0  Aquatics  Water polo       water polo
# 13726   Beijing  2008.0  Aquatics  Water polo       water polo
# 13736   Beijing  2008.0  Aquatics  Water polo       water polo
#
#                      Athlete Gender Country_Code        Country Event_gender  \
# 2       BOGGS, Philip George    Men          USA  United States            M
# ...

# %%
sl.sort_values(by='Athlete')
# Out:
#               City    Year     Sport  Discipline  \
# 7767       Atlanta  1996.0  Aquatics  Water polo
# 13557      Beijing  2008.0  Aquatics    Swimming
# 1569        Moscow  1980.0  Aquatics  Water polo
# 7772       Atlanta  1996.0  Aquatics  Water polo
# 2975   Los Angeles  1984.0  Aquatics  Water polo
# ...            ...     ...       ...         ...
# 9406        Sydney  2000.0  Aquatics      Diving
# 9387        Sydney  2000.0  Aquatics      Diving
# 7520       Atlanta  1996.0  Aquatics      Diving
# 11415       Athens  2004.0  Aquatics      Diving
# 1462        Moscow  1980.0  Aquatics    Swimming
#
#                                     Event             Athlete Gender  \
# 7767                           water polo  ABARCA, Jose Maria    Men
# 13557              4x100m freestyle relay      ADRIAN, Nathan    Men
# 1569                           water polo    AKIMOV, Vladimir    Men
# 7772                           water polo       ANDREO, Angel    Men
# ...

# %% [markdown]
# #which three countries have won the most medals in recent years 1984

# %%
sl1 = oo[oo.Year >= 1984]
sl1.Country_Code.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: Country_Code, dtype: int64

# %% [markdown]
# #display the male gold medals winners for the 100m track & field sprint event over the years, list the results starting whith the most recent. show the olymoic city, Athlete and the count they represent

# %%
sl2 = oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Event == '100m')]
sl2.sort_values('Year', ascending=False)[['Year','Athlete', 'City' ]]
# Out:
#          Year            Athlete         City
# 13839  2008.0        BOLT, Usain      Beijing
# 11901  2004.0     GATLIN, Justin       Athens
# 9850   2000.0    GREENE, Maurice       Sydney
# 7881   1996.0    BAILEY, Donovan      Atlanta
# 6198   1992.0  CHRISTIE, Linford    Barcelona
# 4587   1988.0        LEWIS, Carl        Seoul
# 3052   1984.0        LEWIS, Carl  Los Angeles
# 1657   1980.0       WELLS, Allan       Moscow
# 308    1976.0   CRAWFORD, Hasely     Montreal

# %% [markdown]
# #matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
oo.head(10)
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
# 5  Montreal  1976.0  Aquatics     Diving    10m platform
# 6  Montreal  1976.0  Aquatics     Diving    10m platform
# 7  Montreal  1976.0  Aquatics     Diving  3m springboard
# 8  Montreal  1976.0  Aquatics     Diving    10m platform
# 9  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                      Athlete Gender Country_Code        Country Event_gender  \
# 0            KÖHLER, Christa  Women          GDR   East Germany            W
# 1        KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2       BOGGS, Philip George    Men          USA  United States            M
# ...

# %%
fo = oo[oo.Year == 1976]
fo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %% [markdown]
# #line plot

# %%
fo.Sport.value_counts().plot(kind = 'line');

# %% [markdown]
# #bar plot

# %%
fo.Sport.value_counts().plot(kind = 'bar');

# %% [markdown]
# horizontal bar

# %%
fo.Sport.value_counts().plot(kind = 'barh', color = 'red');

# %% [markdown]
# pie chart

# %%
fo.Sport.value_counts().plot(kind = 'pie');

# %% [markdown]
# #fig size

# %%
fo.Sport.value_counts().plot(figsize = (10, 3));

# %% [markdown]
# #colormaps

# %%
fo.Sport.value_counts().plot(kind = 'pie', colormap = 'Pastel1');

# %% [markdown]
# #seaborn

# %%
import seaborn as sns

# %% [markdown]
# ####how many medals have been won by men and woman in the history of the olympics. how many gold, silver and bronz medals were won for each gender

# %%
sns.countplot(x='Medal', data=oo , hue='Gender');

# %% [markdown]
# #challenge

# %% [markdown]
# ###plot the number of medals achieved by the chinese team(men and women) in Beijing 2008 using matplotlib/seaborn

# %%
oo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
oo1 = oo[(oo.City == 'Beijing') & (oo.Year == 2008)] 
oo1.head()
# Out:
#           City    Year     Sport Discipline  \
# 13391  Beijing  2008.0  Aquatics     Diving
# 13392  Beijing  2008.0  Aquatics     Diving
# 13393  Beijing  2008.0  Aquatics     Diving
# 13394  Beijing  2008.0  Aquatics     Diving
# 13395  Beijing  2008.0  Aquatics     Diving
#
#                                     Event             Athlete Gender  \
# 13391                      3m springboard            QIN, Kai    Men
# 13392    synchronized diving 10m platform            LIN, Yue    Men
# 13393    synchronized diving 10m platform         WU, Melissa  Women
# 13394    synchronized diving 10m platform  DOBROSKOK, Dmitriy    Men
# 13395  synchronized diving 3m springboard       GUO, Jingjing  Women
#
#       Country_Code    Country Event_gender   Medal
# 13391          CHN      China            M  Bronze
# 13392          CHN      China            M    Gold
# 13393          AUS  Australia            W  Silver
# 13394          RUS     Russia            M  Bronze
# ...

# %%
oo1.Medal.value_counts()
# Out:
# Bronze    710
# Gold      669
# Silver    663
# Name: Medal, dtype: int64

# %%
sns.countplot(x='Medal', data=oo1 , hue='Gender');

# %%
oo1.Gender.value_counts().plot(kind = 'bar')

# %% [markdown]
# #index

# %%
oo.set_index('Year')
# Out:
#             City      Sport       Discipline           Event  \
# Year
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving    10m platform
# ...          ...        ...              ...             ...
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                          Athlete Gender Country_Code        Country  \
# Year
# 1976.0           KÖHLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# ...

# %%
oo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
oo.set_index('Year', inplace = True)

# %%
oo.head()
# Out:
#    level_0  index    Year      City     Sport Discipline           Event  \
# 0        0      0  1976.0  Montreal  Aquatics     Diving  3m springboard
# 1        1      1  1976.0  Montreal  Aquatics     Diving  3m springboard
# 2        2      2  1976.0  Montreal  Aquatics     Diving  3m springboard
# 3        3      3  1976.0  Montreal  Aquatics     Diving  3m springboard
# 4        4      4  1976.0  Montreal  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
oo.reset_index(inplace = True)

# %%
oo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %% [markdown]
# ##sort_index

# %%
oo3 = oo

# %%
oo3.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
oo3.set_index('Athlete', inplace = True)

# %%
oo3.head()
# Out:
#                               City    Year     Sport Discipline  \
# Athlete
# KÖHLER, Christa           Montreal  1976.0  Aquatics     Diving
# KOSENKOV, Aleksandr       Montreal  1976.0  Aquatics     Diving
# BOGGS, Philip George      Montreal  1976.0  Aquatics     Diving
# CAGNOTTO, Giorgio Franco  Montreal  1976.0  Aquatics     Diving
# WILSON, Deborah Keplar    Montreal  1976.0  Aquatics     Diving
#
#                                    Event Gender Country_Code        Country  \
# Athlete
# KÖHLER, Christa           3m springboard  Women          GDR   East Germany
# KOSENKOV, Aleksandr       3m springboard    Men          URS   Soviet Union
# BOGGS, Philip George      3m springboard    Men          USA  United States
# CAGNOTTO, Giorgio Franco  3m springboard    Men          ITA          Italy
# WILSON, Deborah Keplar      10m platform  Women          USA  United States
#
#                          Event_gender   Medal
# Athlete
# KÖHLER, Christa                     W  Silver
# ...

# %%
oo3.sort_index()
# Out:
#                           City    Year     Sport Discipline  \
# Athlete
# AAMODT, Ragnhild       Beijing  2008.0  Handball   Handball
# AARDENBURG, Willemien    Seoul  1988.0    Hockey     Hockey
# AARDEWIJN, Pepijn      Atlanta  1996.0    Rowing     Rowing
# AARONES, Ann Kristin   Atlanta  1996.0  Football   Football
# ABAJO, Jose Luis       Beijing  2008.0   Fencing    Fencing
# ...                        ...     ...       ...        ...
# NaN                        NaN     NaN       NaN        NaN
# NaN                        NaN     NaN       NaN        NaN
# NaN                        NaN     NaN       NaN        NaN
# NaN                        NaN     NaN       NaN        NaN
# NaN                        NaN     NaN       NaN        NaN
#
#                                                 Event Gender Country_Code  \
# Athlete
# AAMODT, Ragnhild                             handball  Women          NOR
# AARDENBURG, Willemien                          hockey  Women          NED
# ...

# %% [markdown]
# ##loc[]

# %%
oo.loc['BOLT, Usain']
# Out:
#                 City    Year      Sport Discipline         Event Gender  \
# Athlete
# BOLT, Usain  Beijing  2008.0  Athletics  Athletics          200m    Men
# BOLT, Usain  Beijing  2008.0  Athletics  Athletics          100m    Men
# BOLT, Usain  Beijing  2008.0  Athletics  Athletics  4x100m relay    Men
#
#             Country_Code  Country Event_gender Medal
# Athlete
# BOLT, Usain          JAM  Jamaica            M  Gold
# BOLT, Usain          JAM  Jamaica            M  Gold
# BOLT, Usain          JAM  Jamaica            M  Gold

# %%
oo.reset_index(inplace=True)

# %%
oo
# Out:
#                         Athlete      City    Year      Sport       Discipline  \
# 0               KÖHLER, Christa  Montreal  1976.0   Aquatics           Diving
# 1           KOSENKOV, Aleksandr  Montreal  1976.0   Aquatics           Diving
# 2          BOGGS, Philip George  Montreal  1976.0   Aquatics           Diving
# 3      CAGNOTTO, Giorgio Franco  Montreal  1976.0   Aquatics           Diving
# 4        WILSON, Deborah Keplar  Montreal  1976.0   Aquatics           Diving
# ...                         ...       ...     ...        ...              ...
# 15428        GUENOT, Christophe   Beijing  2008.0  Wrestling  Wrestling Gre-R
# 15429       KVIRKELIA, Manuchar   Beijing  2008.0  Wrestling  Wrestling Gre-R
# 15430          RAHIMOV, Vitaliy   Beijing  2008.0  Wrestling  Wrestling Gre-R
# 15431            GUENOT, Steeve   Beijing  2008.0  Wrestling  Wrestling Gre-R
# 15432             LOPEZ, Mijain   Beijing  2008.0  Wrestling  Wrestling Gre-R
#
# ...

# %%
oo.iloc[1700]
# Out:
# Athlete         KRACHEVSKAIA, Svetlana
# City                            Moscow
# Year                            1980.0
# Sport                        Athletics
# Discipline                   Athletics
# Event                         shot put
# Gender                           Women
# Country_Code                       URS
# Country                   Soviet Union
# Event_gender                         W
# Medal                           Silver
# Name: 1700, dtype: object

# %%
oo.iloc[[ 1700, 1500, 500] ]
# Out:
#                      Athlete      City    Year      Sport     Discipline  \
# 1700  KRACHEVSKAIA, Svetlana    Moscow  1980.0  Athletics      Athletics
# 1500        METSCHUCK, Caren    Moscow  1980.0   Aquatics       Swimming
# 500         OSOKIN, Vladimir  Montreal  1976.0    Cycling  Cycling Track
#
#                        Event Gender Country_Code       Country Event_gender  \
# 1700                shot put  Women          URS  Soviet Union            W
# 1500  4x100m freestyle relay  Women          GDR  East Germany            W
# 500     Team Pursuit (4000m)    Men          URS  Soviet Union            M
#
#        Medal
# 1700  Silver
# 1500    Gold
# 500   Silver

# %%
oo.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %% [markdown]
# ##plot the total number of medals awarded at each of the Olympic games throughout history

# %%
oo.Year.value_counts().sort_index().plot();

# %% [markdown]
# ##Groupby

# %%
list(oo.groupby('Year'))
# Out:
# [(1976.0,
#             City    Year      Sport       Discipline                     Event  \
#   0     Montreal  1976.0   Aquatics           Diving            3m springboard
#   1     Montreal  1976.0   Aquatics           Diving            3m springboard
#   2     Montreal  1976.0   Aquatics           Diving            3m springboard
#   3     Montreal  1976.0   Aquatics           Diving            3m springboard
#   4     Montreal  1976.0   Aquatics           Diving              10m platform
#   ...        ...     ...        ...              ...                       ...
#   1417  Montreal  1976.0  Wrestling  Wrestling Gre-R     48 - 52kg (flyweight)
#   1418  Montreal  1976.0  Wrestling  Wrestling Gre-R  90 - 100kg (heavyweight)
#   1419  Montreal  1976.0  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
#   1420  Montreal  1976.0  Wrestling  Wrestling Gre-R  52 - 57kg (bantamweight)
#   1421  Montreal  1976.0  Wrestling  Wrestling Gre-R  - 48kg (light-flyweight)
#
# ...

# %%
oo.groupby('Year')

# %% [markdown]
# Iterating through groups

# %%
for group_key, group_value in oo.groupby('Year'):
  print(group_key)
  print(group_value)

# %% [markdown]
# ###groupby computations

# %%
oo.groupby('Year').size()
# Out:
# Year
# 1976.0    1305
# 1980.0    1387
# 1984.0    1459
# 1988.0    1546
# 1992.0    1705
# 1996.0    1859
# 2000.0    2015
# 2004.0    1998
# 2008.0    2042
# dtype: int64

# %%
oo.groupby([ 'Year','Country_Code', 'Medal'] ).agg(['min','max', 'count'])
# Out:
#                                 City                          Sport  \
#                                  min       max count            min
# Year   Country_Code Medal
# 1976.0 AUS          Bronze  Montreal  Montreal     8       Aquatics
#                     Silver  Montreal  Montreal    16         Hockey
#        AUT          Bronze  Montreal  Montreal     1       Shooting
#        BEL          Bronze  Montreal  Montreal     6      Athletics
#                     Silver  Montreal  Montreal     3      Athletics
# ...                              ...       ...   ...            ...
# 2008.0 UZB          Silver   Beijing   Beijing     2           Judo
#        VEN          Bronze   Beijing   Beijing     1      Taekwondo
#        VIE          Silver   Beijing   Beijing     1  Weightlifting
#        ZIM          Gold     Beijing   Beijing     1       Aquatics
#                     Silver   Beijing   Beijing     3       Aquatics
#
# ...

# %%
oo.groupby([ 'Year','Country_Code', 'Medal'] ).agg('count')
# Out:
#                             City  Sport  Discipline  Event  Athlete  Gender  \
# Year   Country_Code Medal
# 1976.0 AUS          Bronze     8      8           8      8        8       8
#                     Silver    16     16          16     16       16      16
#        AUT          Bronze     1      1           1      1        1       1
#        BEL          Bronze     6      6           6      6        6       6
#                     Silver     3      3           3      3        3       3
# ...                          ...    ...         ...    ...      ...     ...
# 2008.0 UZB          Silver     2      2           2      2        2       2
#        VEN          Bronze     1      1           1      1        1       1
#        VIE          Silver     1      1           1      1        1       1
#        ZIM          Gold       1      1           1      1        1       1
#                     Silver     3      3           3      3        3       3
#
# ...

# %%
oo.groupby([ 'Year','Country_Code', 'Medal'] ).agg('count')

# %%
oo.loc[oo.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Year': ['min', 'max', 'count']})
# Out:
#                Year
#                 min     max count
# Athlete
# LEWIS, Carl  1984.0  1996.0    10

# %% [markdown]
# ## using groupby(), plot the total number of medals awarded at each of the olympics games throughout history

# %%
oo.groupby('Year').size().plot()

# %% [markdown]
# ##create a list showing the total number of medals won for each country over the hitory oif the oympoucs for each cpuntry include the year of the first and most recent olympic medal wins

# %%
oo.groupby('Country').agg({'Year': [ 'count', 'min', 'max']})
# Out:
#                  Year
#                 count     min     max
# Country
# Afghanistan         1  2008.0  2008.0
# Algeria            14  1984.0  2008.0
# Argentina         153  1988.0  2008.0
# Armenia             9  1996.0  2008.0
# Australia         798  1976.0  2008.0
# ...               ...     ...     ...
# Virgin Islands*     1  1988.0  1988.0
# West Germany      345  1976.0  1988.0
# Yugoslavia        278  1976.0  2000.0
# Zambia              2  1984.0  1996.0
# Zimbabwe           23  1980.0  2008.0
#
# [127 rows x 3 columns]

# %% [markdown]
# ##stack()
